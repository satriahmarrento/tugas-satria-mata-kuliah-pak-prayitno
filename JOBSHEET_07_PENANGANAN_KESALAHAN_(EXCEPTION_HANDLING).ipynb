# %% [markdown]
# <a href="https://colab.research.google.com/github/satriahmarrento/tugas-satria-mata-kuliah-pak-prayitno/blob/main/JOBSHEET_07_PENANGANAN_KESALAHAN_(EXCEPTION_HANDLING).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Praktikum 01: try...except Dasar dalam Metode Kelas

# %%
class DataStore:
    def __init__(self, nama_store="Default Store"):
        # Dictionary internal untuk menyimpan data (ditandai 'protected')
        self._data = {}
        self.nama = nama_store
        print(f"DataStore '{self.nama}' dibuat.")

    def tambah_data(self, key, value):
        """Menambahkan data ke dalam store."""
        print(f"[{self.nama}] Menambahkan data: '{key}' -> {value}")
        self._data[key] = value
        print(" -> Data berhasil ditambahkan.")

    def get_data(self, key):
        """
        Mencoba mendapatkan data berdasarkan key.
        Menangani KeyError jika key tidak ada.
        """
        print(f"[{self.nama}] Mencoba mengambil data dengan key: '{key}'")
        try:
            # Baris ini berpotensi menimbulkan KeyError
            nilai = self._data[key]
            print(f" -> Data ditemukan: {nilai}")
            return nilai
        except KeyError:
            # Blok ini dijalankan jika KeyError terjadi di blok try
            print(f" -> ERROR: Key '{key}' tidak ditemukan di DataStore '{self.nama}'.")
            # Mengembalikan None sebagai indikasi gagal
            return None

# --- Kode Utama ---
if __name__ == "__main__":
    store_produk = DataStore("Toko Produk")
    store_produk.tambah_data("Buku Tulis", 15000)
    store_produk.tambah_data("Pensil 2B", 2000)

    print("\nMengambil data yang ADA:")
    harga_buku = store_produk.get_data("Buku Tulis")
    if harga_buku is not None:
        print(f" Harga Buku Tulis adalah: {harga_buku}")

    print("\nMengambil data yang TIDAK ADA:")
    harga_penggaris = store_produk.get_data("Penggaris")
    if harga_penggaris is None:
        print(" Harga Penggaris tidak ditemukan (sesuai ekspektasi).")
# Out:
# DataStore 'Toko Produk' dibuat.
# [Toko Produk] Menambahkan data: 'Buku Tulis' -> 15000
#  -> Data berhasil ditambahkan.
# [Toko Produk] Menambahkan data: 'Pensil 2B' -> 2000
#  -> Data berhasil ditambahkan.
#
# Mengambil data yang ADA:
# [Toko Produk] Mencoba mengambil data dengan key: 'Buku Tulis'
#  -> Data ditemukan: 15000
#  Harga Buku Tulis adalah: 15000
#
# Mengambil data yang TIDAK ADA:
# [Toko Produk] Mencoba mengambil data dengan key: 'Penggaris'
#  -> ERROR: Key 'Penggaris' tidak ditemukan di DataStore 'Toko Produk'.
#  Harga Penggaris tidak ditemukan (sesuai ekspektasi).

# %% [markdown]
# Praktikum 02: Menangani Beberapa Exception Spesifik

# %%
class KalkulatorAngka:
    def __init__(self):
        print("Kalkulator Angka siap.")

    def bagi(self, angka1, angka2):
        """
        Membagi angka1 dengan angka2.
        Menangani ValueError dan ZeroDivisionError secara terpisah.
        """
        print(f"\nMencoba membagi '{angka1}' dengan '{angka2}'...")
        try:
            # Konversi input ke float, bisa memicu ValueError
            num1 = float(angka1)
            num2 = float(angka2)
            # Operasi pembagian, bisa memicu ZeroDivisionError
            hasil = num1 / num2
            print(f" -> Hasil pembagian: {hasil}")
            return hasil
        except ValueError:
            print(" -> ERROR: Input tidak valid! Pastikan kedua input adalah angka.")
            return None
        except ZeroDivisionError:
            print(" -> ERROR: Tidak bisa melakukan pembagian dengan nol.")
            return None
        except Exception as e:
            print(f" -> ERROR Lainnya: Terjadi kesalahan {e}")
            return None

# --- Kode Utama ---
if __name__ == "__main__":
    calc = KalkulatorAngka()
    print("--- Tes Kalkulator ---")
    calc.bagi(100, 5)            # Sukses
    calc.bagi(20, 0)             # ZeroDivisionError
    calc.bagi("limapuluh", 10)   # ValueError
    calc.bagi(50, "sepuluh")     # ValueError
# Out:
# Kalkulator Angka siap.
# --- Tes Kalkulator ---
#
# Mencoba membagi '100' dengan '5'...
#  -> Hasil pembagian: 20.0
#
# Mencoba membagi '20' dengan '0'...
#  -> ERROR: Tidak bisa melakukan pembagian dengan nol.
#
# Mencoba membagi 'limapuluh' dengan '10'...
#  -> ERROR: Input tidak valid! Pastikan kedua input adalah angka.
#
# Mencoba membagi '50' dengan 'sepuluh'...
#  -> ERROR: Input tidak valid! Pastikan kedua input adalah angka.

# %% [markdown]
# Praktikum 03: Menggunakan else dan finally dalam Metode

# %%
import os

class FileProcessor:
    def __init__(self, nama_file):
        self.nama_file = nama_file
        self._file_handle = None
        print(f"\n-> FileProcessor dibuat untuk file: '{self.nama_file}'")

    def baca_dan_proses(self):
        print(f"[{self.nama_file}] Mencoba memproses...")
        try:
            print(f" [{self.nama_file}] Membuka file...")
            self._file_handle = open(self.nama_file, 'r', encoding='utf-8')

            print(f" [{self.nama_file}] Membaca isi file...")
            isi = self._file_handle.read()
            print(f" -> File berhasil dibaca.")

            print(f" [{self.nama_file}] Memproses isi...")
            print(f" -> Panjang isi: {len(isi)} karakter.")
        except FileNotFoundError:
            print(f" -> ERROR: File '{self.nama_file}' tidak ditemukan.")
        except Exception as e:
            print(f" -> ERROR Lainnya saat memproses file: {e}")
        else:
            print(f" -> PEMROSESAN BERHASIL: Tidak ada error terjadi pada '{self.nama_file}'.")
        finally:
            print(f" [{self.nama_file}] Blok Finally: Melakukan cleanup...")
            if self._file_handle and not self._file_handle.closed:
                print(f" -> Menutup file '{self.nama_file}'...")
                self._file_handle.close()
                print(" -> File berhasil ditutup.")
            else:
                print(" -> File tidak perlu ditutup (belum dibuka atau sudah ditutup).")
            print(f"[{self.nama_file}] Selesai mencoba proses.\n" + "-"*30)

# --- Kode Utama ---
if __name__ == "__main__":
    FILE_OK = "data_penting.txt"
    # Buat file dummy
    with open(FILE_OK, "w", encoding='utf-8') as f:
        f.write("Data penting praktikum.")

    proc1 = FileProcessor(FILE_OK)
    proc1.baca_dan_proses()

    proc2 = FileProcessor("file_palsu.txt")
    proc2.baca_dan_proses()

    if os.path.exists(FILE_OK): os.remove(FILE_OK)
# Out:
# -> FileProcessor dibuat untuk file: 'data_penting.txt'
# [data_penting.txt] Mencoba memproses...
#  [data_penting.txt] Membuka file...
#  [data_penting.txt] Membaca isi file...
#  -> File berhasil dibaca.
#  [data_penting.txt] Memproses isi...
#  -> Panjang isi: 23 karakter.
#  -> PEMROSESAN BERHASIL: Tidak ada error terjadi pada 'data_penting.txt'.
#  [data_penting.txt] Blok Finally: Melakukan cleanup...
#  -> Menutup file 'data_penting.txt'...
#  -> File berhasil ditutup.
# [data_penting.txt] Selesai mencoba proses.
# ------------------------------
#
# -> FileProcessor dibuat untuk file: 'file_palsu.txt'
# [file_palsu.txt] Mencoba memproses...
#  [file_palsu.txt] Membuka file...
#  -> ERROR: File 'file_palsu.txt' tidak ditemukan.
#  [file_palsu.txt] Blok Finally: Melakukan cleanup...
#  -> File tidak perlu ditutup (belum dibuka atau sudah ditutup).
# [file_palsu.txt] Selesai mencoba proses.
# ------------------------------

# %% [markdown]
# Praktikum 04: Mengakses Objek Exception (as e)

# %%
class KalkulatorAngka:
    def bagi(self, angka1, angka2):
        print(f"\nMencoba membagi '{angka1}' dengan '{angka2}'...")
        try:
            num1 = float(angka1)
            num2 = float(angka2)
            if num2 == 0:
                raise ZeroDivisionError("Pembagi tidak boleh nol secara eksplisit.")
            hasil = num1 / num2
            return hasil
        except ValueError as e_val:
            print(f" -> ERROR Konversi: Input tidak valid.")
            print(f" Detail Error: {e_val}")
        except ZeroDivisionError as e_zero:
            print(f" -> ERROR Pembagian: {e_zero}")
        except Exception as e:
            print(f" -> ERROR Tak Terduga: {type(e).__name__} - {e}")
        return None

if __name__ == "__main__":
    calc = KalkulatorAngka()
    calc.bagi(10, []) # Memicu TypeError yang ditangkap except Exception
# Out:
# Mencoba membagi '10' dengan '[]'...
#  -> ERROR Tak Terduga: TypeError - float() argument must be a string or a real number, not 'list'

# %% [markdown]
# Praktikum 05: Membangkitkan Exception (raise)

# %%
class PengelolaAkun:
    def __init__(self, nomor_akun, saldo_awal=0):
        if saldo_awal < 0:
            raise ValueError(f"Saldo awal ({saldo_awal}) tidak boleh negatif.")
        self.nomor_akun = nomor_akun
        self._saldo = float(saldo_awal)

    def tarik_tunai(self, jumlah):
        if jumlah <= 0:
            raise ValueError(f"Jumlah penarikan ({jumlah}) harus positif.")
        if jumlah > self._saldo:
            raise RuntimeError(f"Saldo tidak cukup! Saldo: {self._saldo}, Diminta: {jumlah}")
        self._saldo -= jumlah
        print(f"Penarikan {jumlah} sukses. Sisa saldo: {self._saldo}")

if __name__ == "__main__":
    try:
        akun = PengelolaAkun("ACC002", 100000)
        akun.tarik_tunai(150000) # Akan memicu RuntimeError
    except (ValueError, RuntimeError) as e:
        print(f"ERROR DITANGKAP: {e}")
# Out:
# ERROR DITANGKAP: Saldo tidak cukup! Saldo: 100000.0, Diminta: 150000

# %% [markdown]
# Praktikum 6: Kombinasi Menangkap dan  Membangkitkan Exception

# %%
# 1. Definisikan Custom Exception (mewarisi dari Exception)
class KonfigurasiError(Exception):
    """Exception khusus untuk menandakan error terkait konfigurasi aplikasi."""
    def __init__(self, message, penyebab_asli=None):
        super().__init__(message)
        self.penyebab_asli = penyebab_asli  # Menyimpan error asli jika ada

    def __str__(self):
        if self.penyebab_asli:
            return f"{super().__str__()} (Disebabkan oleh: {type(self.penyebab_asli).__name__})"
        return super().__str__()

# 2. Kelas yang menggunakan exception handling gabungan
class PengelolaSetting:
    def __init__(self, file_config):
        self._config = {}
        self.file_config = file_config
        print(f"\n-> PengelolaSetting berhasil dibuat untuk '{self.file_config}'.")

        # Panggil metode internal yang berpotensi raise KonfigurasiError
        try:
            self._load_config()
        except KonfigurasiError as e:
            print(f"-> GAGAL membuat PengelolaSetting: {e}")
            # Bisa jadi kita ingin raise lagi agar pembuat objek tahu ada masalah serius
            # raise e
            # Atau set state default / kosong
            self._config = {}
            print("   -> Menggunakan konfigurasi default/kosong.")

    def _load_config(self):
        """Metode internal untuk load config. Bisa raise KonfigurasiError."""
        print(f"\n   [{self.file_config}] Mencoba load konfigurasi...")
        try:
            # 1. Potensi FileNotFoundError
            print(f"      Membuka file '{self.file_config}'...")
            # Simulasi: anggap hanya file 'config.txt' yang valid untuk dibaca
            if self.file_config != 'config.txt':
                # Jika file tidak ada, kita raise FileNotFoundError secara manual
                raise FileNotFoundError(f"File '{self.file_config}' tidak ada.")

            # 2. Potensi Error Isi File (KeyError, ValueError)
            print(f"      Membaca dan validasi isi '{self.file_config}'...")

            # Simulasi data raw (kamu bisa ubah komentar di bawah untuk tes skenario berbeda)
            # data_raw = {"host": "192.168.1.1", "port": "8080"}  # Port benar
            data_raw = {"host": "192.168.1.1", "port": "xyz"}     # Port salah tipe (ValueError)
            # data_raw = {"host": "192.168.1.1"}                  # Key 'port' hilang (KeyError)

            # Cek key 'port'
            port_str = data_raw['port']  # Bisa raise KeyError

            # Cek tipe 'port'
            port_int = int(port_str)     # Bisa raise ValueError

            # Jika lolos, simpan
            self._config['port'] = port_int
            self._config['host'] = data_raw.get('host', 'localhost')
            print("   -> Konfigurasi berhasil di-load dan divalidasi.")

        # Blok Except
        except FileNotFoundError as e_fnf:
            print(f"      ERROR Bawaan: File tidak ditemukan.")
            # Re-raise sebagai KonfigurasiError
            raise KonfigurasiError(f"File konfigurasi penting '{self.file_config}' hilang.", penyebab_asli=e_fnf) from e_fnf

        except KeyError as e_key:
            print(f"      ERROR Bawaan: Kunci konfigurasi hilang.")
            # Re-raise sebagai KonfigurasiError
            raise KonfigurasiError(f"Kunci '{e_key}' wajib ada dalam file konfigurasi.", penyebab_asli=e_key) from e_key

        except ValueError as e_val:
            print(f"      ERROR Bawaan: Nilai konfigurasi tidak valid.")
            # Re-raise sebagai KonfigurasiError
            raise KonfigurasiError(f"Nilai untuk 'port' ('{port_str}') harus integer.", penyebab_asli=e_val) from e_val

        except Exception as e_lain:
            print(f"      ERROR Bawaan Tak Terduga: {type(e_lain).__name__}")
            # Re-raise sebagai KonfigurasiError umum
            raise KonfigurasiError(f"Terjadi error tak terduga saat memuat konfigurasi.", penyebab_asli=e_lain) from e_lain

    def get_setting(self, key, default=None):
        """Mendapatkan nilai setting."""
        return self._config.get(key, default)


# 3. Kode Utama
if __name__ == "__main__":
    # Skenario 1: File tidak ada -> Menghasilkan KonfigurasiError
    print("\n--- Skenario 1: File Salah ---")
    settings1 = PengelolaSetting("setting.cfg")
    print(f"Port dari settings1: {settings1.get_setting('port', 'Belum terload')}")

    # Skenario 2: File ada, tapi data port salah -> Menghasilkan KonfigurasiError
    print("\n--- Skenario 2: Data Port Salah ---")
    settings2 = PengelolaSetting("config.txt")
    print(f"Port dari settings2: {settings2.get_setting('port', 'Belum terload')}")

    # Skenario 3: Sukses (Silakan ubah 'data_raw' di atas menjadi yang benar untuk mencoba ini)
    # print("\n--- Skenario 3: Sukses ---")
    # settings3 = PengelolaSetting("config.txt")
    # print(f"Port dari settings3: {settings3.get_setting('port')}")
    # print(f"Host dari settings3: {settings3.get_setting('host')}")
# Out:
# --- Skenario 1: File Salah ---
#
# -> PengelolaSetting berhasil dibuat untuk 'setting.cfg'.
#
#    [setting.cfg] Mencoba load konfigurasi...
#       Membuka file 'setting.cfg'...
#       ERROR Bawaan: File tidak ditemukan.
# -> GAGAL membuat PengelolaSetting: File konfigurasi penting 'setting.cfg' hilang. (Disebabkan oleh: FileNotFoundError)
#    -> Menggunakan konfigurasi default/kosong.
# Port dari settings1: Belum terload
#
# --- Skenario 2: Data Port Salah ---
#
# -> PengelolaSetting berhasil dibuat untuk 'config.txt'.
#
#    [config.txt] Mencoba load konfigurasi...
#       Membuka file 'config.txt'...
#       Membaca dan validasi isi 'config.txt'...
#       ERROR Bawaan: Nilai konfigurasi tidak valid.
# -> GAGAL membuat PengelolaSetting: Nilai untuk 'port' ('xyz') harus integer. (Disebabkan oleh: ValueError)
#    -> Menggunakan konfigurasi default/kosong.
# Port dari settings2: Belum terload

# %% [markdown]
# Penugasan

# %%
class InventarisBarang:
    def __init__(self):
        self._items = {}

    def tambah_barang(self, kode, jumlah):
        try:
            jumlah_int = int(jumlah)
            if jumlah_int <= 0:
                raise ValueError
        except ValueError:
            print("Error: Jumlah barang harus berupa integer positif.")
            return

        if kode in self._items:
            raise KeyError(f"Error: Kode barang '{kode}' sudah ada.")

        self._items[kode] = jumlah_int
        print(f"Sukses: Barang '{kode}' ditambahkan dengan stok awal {jumlah_int}.")

    def ambil_barang(self, kode, jumlah):
        try:
            jumlah_int = int(jumlah)
            if jumlah_int <= 0:
                raise ValueError
        except ValueError:
            print("Error: Jumlah pengambilan harus berupa integer positif.")
            return

        try:
            stok_sekarang = self._items[kode]
        except KeyError:
            print(f"Error: Kode barang '{kode}' tidak ditemukan.")
            return

        if jumlah_int > stok_sekarang:
            raise ValueError(f"Error: Stok barang '{kode}' tidak mencukupi (tersedia: {stok_sekarang}, diminta: {jumlah_int}).")

        self._items[kode] -= jumlah_int
        print(f"Sukses: {jumlah_int} unit barang '{kode}' diambil. Sisa stok: {self._items[kode]}.")

    def cek_stok(self, kode):
        try:
            stok = self._items[kode]
        except KeyError:
            print(f"Pencarian Error: Barang '{kode}' tidak ditemukan di inventaris.")
        else:
            print(f"Info Stok: Barang '{kode}' memiliki sisa stok {stok} unit.")
        finally:
            print(f"-> Pengecekan stok untuk kode '{kode}' selesai.\n")


if __name__ == "__main__":
    toko = InventarisBarang()

    print("--- UJI COBA: TAMBAH BARANG ---")
    toko.tambah_barang("A001", 50)
    toko.tambah_barang("A002", 150)

    try:
        toko.tambah_barang("A001", 20)
    except KeyError as e:
        print(e)

    print("\n--- UJI COBA: AMBIL BARANG ---")
    toko.ambil_barang("A002", -10)
    toko.ambil_barang("Z999", 5)

    try:
        toko.ambil_barang("A001", 100)
    except ValueError as e:
        print(e)

    try:
        toko.ambil_barang("A002", 50)
    except Exception as e:
        print(f"Terjadi error: {e}")

    print("\n--- UJI COBA: CEK STOK ---")
    toko.cek_stok("A001")
    toko.cek_stok("Z999")
# Out:
# --- UJI COBA: TAMBAH BARANG ---
# Sukses: Barang 'A001' ditambahkan dengan stok awal 50.
# Sukses: Barang 'A002' ditambahkan dengan stok awal 150.
# "Error: Kode barang 'A001' sudah ada."
#
# --- UJI COBA: AMBIL BARANG ---
# Error: Jumlah pengambilan harus berupa integer positif.
# Error: Kode barang 'Z999' tidak ditemukan.
# Error: Stok barang 'A001' tidak mencukupi (tersedia: 50, diminta: 100).
# Sukses: 50 unit barang 'A002' diambil. Sisa stok: 100.
#
# --- UJI COBA: CEK STOK ---
# Info Stok: Barang 'A001' memiliki sisa stok 50 unit.
# -> Pengecekan stok untuk kode 'A001' selesai.
#
# Pencarian Error: Barang 'Z999' tidak ditemukan di inventaris.
# -> Pengecekan stok untuk kode 'Z999' selesai.
